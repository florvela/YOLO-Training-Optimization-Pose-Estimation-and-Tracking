# %% [markdown]
# [![Roboflow Notebooks](https://ik.imagekit.io/roboflow/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Train YOLOv8 Object Detection on a Custom Dataset
#
# ---
#
# [![Roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/how-to-train-yolov8-on-a-custom-dataset)
# [![YouTube](https://badges.aleen42.com/src/youtube.svg)](https://youtu.be/wuZtUMEiKWY)
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/ultralytics/ultralytics)
#
# Ultralytics YOLOv8 is the latest version of the YOLO (You Only Look Once) object detection and image segmentation model developed by Ultralytics. The YOLOv8 model is designed to be fast, accurate, and easy to use, making it an excellent choice for a wide range of object detection and image segmentation tasks. It can be trained on large datasets and is capable of running on a variety of hardware platforms, from CPUs to GPUs.
#
# ## ⚠️ Disclaimer
#
# YOLOv8 is still under heavy development. Breaking changes are being introduced almost weekly. We strive to make our YOLOv8 notebooks work with the latest version of the library. Last tests took place on **27.01.2023** with version **YOLOv8.0.20**.
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.
#
# ## Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the blog post on how to train YOLOv8 Object Detection, concurrently.
#
# ## Pro Tip: Use GPU Acceleration
#
# If you are running this notebook in Google Colab, navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`. This will ensure your notebook uses a GPU, which will significantly speed up model training times.
#
# ## Steps in this Tutorial
#
# In this tutorial, we are going to cover:
#
# - Before you start
# - Install YOLOv8
# - CLI Basics
# - Inference with Pre-trained COCO Model
# - Roboflow Universe
# - Preparing a custom dataset
# - Custom Training
# - Validate Custom Model
# - Inference with Custom Model
#
# **Let's begin!**

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Sun May 21 20:02:31 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   61C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install YOLOv8
#
# ⚠️ YOLOv8 is still under heavy development. Breaking changes are being introduced almost weekly. We strive to make our YOLOv8 notebooks work with the latest version of the library. Last tests took place on **27.01.2023** with version **YOLOv8.0.20**.
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.
#
# YOLOv8 can be installed in two ways - from the source and via pip. This is because it is the first iteration of YOLO to have an official package.

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/78.2 GB disk)

# %%
# Git clone method (for development)

# %cd {HOME}
# !git clone github.com/ultralytics/ultralytics
# %cd {HOME}/ultralytics
# !pip install -e .

# from IPython import display
# display.clear_output()

# import ultralytics
# ultralytics.checks()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## CLI Basics

# %% [markdown]
# If you want to train, validate or run inference on models and don't need to make any modifications to the code, using YOLO command line interface is the easiest way to get started. Read more about CLI in [Ultralytics YOLO Docs](https://docs.ultralytics.com/usage/cli/).
#
# ```
# yolo task=detect    mode=train    model=yolov8n.yaml      args...
#           classify       predict        yolov8n-cls.yaml  args...
#           segment        val            yolov8n-seg.yaml  args...
#                          export         yolov8n.pt        format=onnx  args...
# ```

# %% [markdown]
# ## Inference with Pre-trained COCO Model

# %% [markdown]
# ### 💻 CLI

# %% [markdown]
# `yolo mode=predict` runs YOLOv8 inference on a variety of sources, downloading models automatically from the latest YOLOv8 release, and saving results to `runs/predict`.

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
# 100% 6.23M/6.23M [00:00<00:00, 68.5MB/s]
#
# 2023-05-21 20:02:58.491352: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-21 20:02:59.780535: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# Downloading https://media.roboflow.com/notebooks/examples/dog.jpeg to dog.jpeg...
# 100% 104k/104k [00:00<00:00, 10.8MB/s]
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 206.3ms
# Speed: 0.7ms pre-process, 206.3ms inference, 451.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
# %cd {HOME}
Image(filename='runs/detect/predict/dog.jpeg', height=600)
# Out:
# /content

# %% [markdown]
# ### 🐍 Python SDK
#
# The simplest way of simply using YOLOv8 directly in a Python environment.

# %%
model = YOLO(f'{HOME}/yolov8n.pt')
results = model.predict(source='https://media.roboflow.com/notebooks/examples/dog.jpeg', conf=0.25)
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg

# %%
results[0].boxes.xyxy
# Out:
# tensor([[   0.,  314.,  625., 1278.],
#         [  55.,  250.,  648., 1266.],
#         [ 633.,  720.,  701.,  786.]], device='cuda:0')

# %%
results[0].boxes.conf
# Out:
# tensor([0.72713, 0.29066, 0.28456], device='cuda:0')

# %%
results[0].boxes.cls
# Out:
# tensor([ 0., 16.,  2.], device='cuda:0')

# %% [markdown]
# ## Roboflow Universe
#
# Need data for your project? Before spending time on annotating, check out Roboflow Universe, a repository of more than 110,000 open-source datasets that you can use in your projects. You'll find datasets containing everything from annotated cracks in concrete to plant images with disease annotations.
#
#
# [![Roboflow Universe](https://ik.imagekit.io/roboflow/notebooks/template/uni-banner-frame.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672878480290)](https://universe.roboflow.com/)

# %% [markdown]
# ## Preparing a custom dataset
#
# Building a custom dataset can be a painful process. It might take dozens or even hundreds of hours to collect images, label them, and export them in the proper format. Fortunately, Roboflow makes this process as straightforward and fast as possible. Let me show you how!
#
# ### Step 1: Creating project
#
# Before you start, you need to create a Roboflow [account](https://app.roboflow.com/login). Once you do that, you can create a new project in the Roboflow [dashboard](https://app.roboflow.com/). Keep in mind to choose the right project type. In our case, Object Detection.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://ik.imagekit.io/roboflow/preparing-custom-dataset-example/creating-project.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672929799852"
#   >
# </div>
#
# ### Step 2: Uploading images
#
# Next, add the data to your newly created project. You can do it via API or through our [web interface](https://docs.roboflow.com/adding-data/object-detection).
#
# If you drag and drop a directory with a dataset in a supported format, the Roboflow dashboard will automatically read the images and annotations together.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://ik.imagekit.io/roboflow/preparing-custom-dataset-example/uploading-images.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672929808290"
#   >
# </div>
#
# ### Step 3: Labeling
#
# If you only have images, you can label them in [Roboflow Annotate](https://docs.roboflow.com/annotate).
#
# <div align="center">
#   <img
#     width="640"
#     src="https://user-images.githubusercontent.com/26109316/210901980-04861efd-dfc0-4a01-9373-13a36b5e1df4.gif"
#   >
# </div>
#
# ### Step 4: Generate new dataset version
#
# Now that we have our images and annotations added, we can Generate a Dataset Version. When Generating a Version, you may elect to add preprocessing and augmentations. This step is completely optional, however, it can allow you to significantly improve the robustness of your model.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/generate-new-version.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1673003597834"
#   >
# </div>
#
# ### Step 5: Exporting dataset
#
# Once the dataset version is generated, we have a hosted dataset we can load directly into our notebook for easy training. Click `Export` and select the `YOLO v5 PyTorch` dataset format.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://ik.imagekit.io/roboflow/preparing-custom-dataset-example/export.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672943313709"
#   >
# </div>

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow --quiet

from roboflow import Roboflow
rf = Roboflow(api_key="TCEd0M8cNgbjG3ppH5z6")
project = rf.workspace("joseph-nelson").project("mask-wearing")
dataset = project.version(19).download("yolov8")
# Out:
# /content/datasets
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 8.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.7 MB/s eta 0:00:00
#   Building wheel for wget (setup.py) ... done
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Mask-Wearing-19 to yolov8: 100% [217445144 / 217445144] bytes
# Extracting Dataset Version Zip to Mask-Wearing-19 in yolov8:: 100%|██████████| 3880/3880 [00:01<00:00, 2282.06it/s]

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=10 imgsz=800 plots=True
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8s.pt to yolov8s.pt...
# 100% 21.5M/21.5M [00:00<00:00, 47.4MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8s.yaml, data=/content/datasets/Mask-Wearing-19/data.yaml, epochs=10, patience=50, batch=16, imgsz=800, save=True, cache=False, device=, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=False, val=True, save_json=False, save_hybrid=False, conf=0.001, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=ultralytics/assets/, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 14.1MB/s]
# 2023-05-21 20:04:41.278381: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.Conv                  [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.C2f                   [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.C2f                   [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.C2f                   [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.SPPF                  [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    591360  ultralytics.nn.modules.C2f                   [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.Conv                  [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.C2f                   [768, 512, 1]
#  22        [15, 18, 21]  1   2116822  ultralytics.nn.modules.Detect                [2, [128, 256, 512]]
# Model summary: 225 layers, 11136374 parameters, 11136358 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.001), 63 bias
# train: Scanning /content/datasets/Mask-Wearing-19/train/labels... 1366 images, 193 backgrounds, 0 corrupt: 100% 1366/1366 [00:00<00:00, 1931.70it/s]
# train: New cache created: /content/datasets/Mask-Wearing-19/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/datasets/Mask-Wearing-19/valid/labels... 368 images, 56 backgrounds, 0 corrupt: 100% 368/368 [00:00<00:00, 2190.27it/s]
# val: New cache created: /content/datasets/Mask-Wearing-19/valid/labels.cache
# Image sizes 800 train, 800 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 10 epochs...
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10       9.2G      1.643      3.397      1.876          6        800: 100% 86/86 [00:59<00:00,  1.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 12/12 [00:14<00:00,  1.18s/it]
#                    all        368        709      0.486      0.434      0.441      0.226
#                   mask        368        476      0.618      0.443      0.529       0.29
#                no-mask        368        233      0.354      0.425      0.354      0.162
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10      11.1G       1.36      1.294      1.499          8        800: 100% 86/86 [00:52<00:00,  1.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 12/12 [00:12<00:00,  1.03s/it]
#                    all        368        709      0.727      0.603      0.695      0.395
#                   mask        368        476      0.656      0.765      0.754      0.427
#                no-mask        368        233      0.797      0.442      0.636      0.363
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10      11.1G      1.322      1.171      1.429         10        800: 100% 86/86 [00:52<00:00,  1.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 12/12 [00:12<00:00,  1.04s/it]
#                    all        368        709      0.707      0.651      0.716      0.423
#                   mask        368        476       0.72      0.713      0.745      0.443
#                no-mask        368        233      0.693      0.588      0.688      0.404
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10      11.1G      1.286      1.122      1.417          5        800: 100% 86/86 [00:51<00:00,  1.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 12/12 [00:12<00:00,  1.04s/it]
#                    all        368        709      0.644      0.665      0.706      0.413
#                   mask        368        476      0.579      0.784      0.771      0.465
#                no-mask        368        233       0.71      0.547      0.641      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10      11.1G      1.281      1.091       1.41         13        800: 100% 86/86 [00:51<00:00,  1.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 12/12 [00:12<00:00,  1.07s/it]
#                    all        368        709      0.753      0.603       0.72      0.417
#                   mask        368        476      0.889       0.58      0.769      0.453
#                no-mask        368        233      0.617      0.627      0.671      0.382
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      11.1G      1.212     0.9572      1.373         18        800: 100% 86/86 [00:53<00:00,  1.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 12/12 [00:12<00:00,  1.05s/it]
#                    all        368        709      0.843      0.728      0.809      0.498
#                   mask        368        476      0.825      0.773       0.85      0.532
#                no-mask        368        233      0.862      0.682      0.768      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10      11.1G      1.157     0.8714      1.331          9        800: 100% 86/86 [00:52<00:00,  1.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 12/12 [00:13<00:00,  1.09s/it]
#                    all        368        709      0.859      0.711      0.849      0.523
#                   mask        368        476      0.902      0.756      0.873      0.537
#                no-mask        368        233      0.816      0.665      0.825      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10      11.1G      1.097     0.8309       1.29         18        800: 100% 86/86 [00:53<00:00,  1.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 12/12 [00:12<00:00,  1.07s/it]
#                    all        368        709      0.897      0.786      0.896      0.594
#                   mask        368        476      0.923      0.753      0.898      0.589
#                no-mask        368        233      0.871       0.82      0.893      0.599
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10      11.1G      1.071     0.7376      1.263          7        800: 100% 86/86 [00:52<00:00,  1.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 12/12 [00:12<00:00,  1.04s/it]
#                    all        368        709      0.903      0.799      0.903      0.607
#                   mask        368        476      0.876        0.8      0.913      0.612
#                no-mask        368        233       0.93      0.797      0.893      0.602
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10      11.1G      1.024     0.6841      1.228          5        800: 100% 86/86 [00:52<00:00,  1.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 12/12 [00:16<00:00,  1.41s/it]
#                    all        368        709       0.88      0.816      0.892      0.619
#                   mask        368        476      0.871      0.805      0.879      0.599
#                no-mask        368        233      0.888      0.828      0.906       0.64
#
# 10 epochs completed in 0.188 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 22.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 12/12 [00:15<00:00,  1.33s/it]
#                    all        368        709       0.88      0.816      0.892       0.62
#                   mask        368        476      0.871      0.805      0.879      0.598
#                no-mask        368        233      0.888      0.828      0.906      0.641
# Speed: 1.9ms pre-process, 5.4ms inference, 0.0ms loss, 4.0ms post-process per image
# Results saved to runs/detect/train

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml					    train_batch1.jpg
# confusion_matrix.png				    train_batch2.jpg
# events.out.tfevents.1684699482.ade5d35cf9fd.1269.0  val_batch0_labels.jpg
# F1_curve.png					    val_batch0_pred.jpg
# P_curve.png					    val_batch1_labels.jpg
# PR_curve.png					    val_batch1_pred.jpg
# R_curve.png					    val_batch2_labels.jpg
# results.csv					    val_batch2_pred.jpg
# results.png					    weights
# train_batch0.jpg

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /content
# 2023-05-21 20:17:04.728685: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/datasets/Mask-Wearing-19/valid/labels.cache... 368 images, 56 backgrounds, 0 corrupt: 100% 368/368 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:15<00:00,  1.47it/s]
#                    all        368        709      0.876      0.821      0.893      0.621
#                   mask        368        476      0.867      0.817       0.88      0.599
#                no-mask        368        233      0.885      0.824      0.907      0.642
# Speed: 2.3ms pre-process, 12.1ms inference, 0.0ms loss, 4.1ms post-process per image

# %% [markdown]
# ## Inference with Custom Model

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True
# Out:
# /content
# 2023-05-21 20:16:34.348946: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# image 1/200 /content/datasets/Mask-Wearing-19/test/images/0209-00176-076b1_jpg.rf.68ca9cf32fcefea879d225af4a7c3d44.jpg: 544x800 5 masks, 2 no-masks, 104.9ms
# image 2/200 /content/datasets/Mask-Wearing-19/test/images/0450908675_50159485_mutation-virus-chine-inquietude_jpg.rf.bda5fb5e13aac2a13eacab5ee4938218.jpg: 512x800 3 masks, 1 no-mask, 94.7ms
# image 3/200 /content/datasets/Mask-Wearing-19/test/images/0_Concern-In-China-As-Mystery-Virus-Spreads_jpg.rf.11f76c39529068ff636fa2242afffa1d.jpg: 448x800 3 masks, 99.4ms
# image 4/200 /content/datasets/Mask-Wearing-19/test/images/0_Concern-In-China-As-Mystery-Virus-Spreads_jpg.rf.8817cb47eb5195e35bd6eee4bc773e68.jpg: 448x800 3 masks, 15.1ms
# image 5/200 /content/datasets/Mask-Wearing-19/test/images/1224331650_g_400-w_g_jpg.rf.4f6fa6b1a07d7011f5e32cf441b0d8d8.jpg: 768x800 5 masks, 106.7ms
# image 38/200 /content/datasets/Mask-Wearing-19/test/images/IMG_8572_MOV-145_jpg.rf.e3f6e6ed03ff0d997ff8e495cc9863f7.jpg: 800x480 1 no-mask, 29.1ms
# image 39/200 /content/datasets/Mask-Wearing-19/test/images/IMG_8572_MOV-146_jpg.rf.0850d02921a14a3120daca38f0ac91cc.jpg: 800x480 15.5ms
# image 40/200 /content/datasets/Mask-Wearing-19/test/images/Inside-merge_mov-12_jpg.rf.d7938a224c5c851f9b83acb19295b737.jpg: 800x480 21.8ms
# image 41/200 /content/datasets/Mask-Wearing-19/test/images/Inside-merge_mov-21_jpg.rf.e42dd433259fe3dff0709d2c65d72bed.jpg: 800x480 16.1ms
# image 42/200 /content/datasets/Mask-Wearing-19/test/images/Inside-merge_mov-22_jpg.rf.b835e3bddd4e4d0c7aff8b0821dafb06.jpg: 800x480 15.5ms
# image 43/200 /content/datasets/Mask-Wearing-19/test/images/Inside-merge_mov-24_jpg.rf.41ac8f8493236ad8f0d7b8b54444254e.jpg: 800x480 1 mask, 21.1ms
# image 44/200 /content/datasets/Mask-Wearing-19/test/images/Inside-merge_mov-32_jpg.rf.84a84e28fb21f31c8648597b405a89d6.jpg: 800x480 15.5ms
# image 45/200 /content/datasets/Mask-Wearing-19/test/images/Mask-detector1_mov-17_jpg.rf.8469495d01554ae12df6e519ddacd41b.jpg: 800x480 1 no-mask, 26.6ms
# image 46/200 /content/datasets/Mask-Wearing-19/test/images/Mask-detector1_mov-19_jpg.rf.9f534c5a52e543e97beba44e730ac8ea.jpg: 800x480 1 no-mask, 19.5ms
# image 47/200 /content/datasets/Mask-Wearing-19/test/images/Mask-detector1_mov-25_jpg.rf.1d350833d38ce50d46001eec50f8384c.jpg: 800x480 1 mask, 15.5ms
# image 48/200 /content/datasets/Mask-Wearing-19/test/images/Mask-detector1_mov-48_jpg.rf.96008e6937d594f5df6db2ed4de00ba6.jpg: 800x480 1 no-mask, 15.5ms
# image 49/200 /content/datasets/Mask-Wearing-19/test/images/Mask-detector1_mov-52_jpg.rf.dda28f81a8b4261a81cc161f0cfe7f51.jpg: 800x480 1 no-mask, 15.8ms
# image 50/200 /content/datasets/Mask-Wearing-19/test/images/Mask-detector1_mov-54_jpg.rf.e204f70610c8002b34323dbf0695c153.jpg: 800x480 1 mask, 15.5ms
# image 51/200 /content/datasets/Mask-Wearing-19/test/images/Mask-detector1_mov-59_jpg.rf.45aedeff78efddfa0a0e97131d4b9d03.jpg: 800x480 1 no-mask, 15.5ms
# image 52/200 /content/datasets/Mask-Wearing-19/test/images/Mask2_mov-23_jpg.rf.20e8cbdb08e371bb6355150cff664d96.jpg: 800x480 1 mask, 15.5ms
# image 53/200 /content/datasets/Mask-Wearing-19/test/images/Mask2_mov-27_jpg.rf.f68acd794eb406ef410dca0fd912736e.jpg: 800x480 1 no-mask, 15.5ms
# image 54/200 /content/datasets/Mask-Wearing-19/test/images/Mask2_mov-2_jpg.rf.4f0452bacf348eeeef8766088b500f0e.jpg: 800x480 1 mask, 1 no-mask, 15.5ms
# image 55/200 /content/datasets/Mask-Wearing-19/test/images/Mask2_mov-39_jpg.rf.2a5e0f34e200c5110321a34891c60244.jpg: 800x480 1 mask, 1 no-mask, 15.5ms
# image 56/200 /content/datasets/Mask-Wearing-19/test/images/Mask2_mov-47_jpg.rf.cea4a786957a257c6af0094771f9936e.jpg: 800x480 1 mask, 1 no-mask, 15.4ms
# image 57/200 /content/datasets/Mask-Wearing-19/test/images/Mask2_mov-6_jpg.rf.36239bc76d2a1277d5b25ca196712afc.jpg: 800x480 1 mask, 15.5ms
# image 58/200 /content/datasets/Mask-Wearing-19/test/images/PXL_20210930_151814022_jpg.rf.2203573796680d3b70606ac6381e02b3.jpg: 608x800 1 mask, 19.4ms
# image 59/200 /content/datasets/Mask-Wearing-19/test/images/PXL_20210930_151819993_jpg.rf.12cba213b7a05e2b87b519f253c8908e.jpg: 608x800 2 masks, 18.5ms
# image 60/200 /content/datasets/Mask-Wearing-19/test/images/PXL_20210930_152000048_jpg.rf.5f57ed1e5d34f55d61025ac0c953bf60.jpg: 608x800 1 mask, 18.4ms
# image 61/200 /content/datasets/Mask-Wearing-19/test/images/PhotoGrid_1580452532909_jpg.rf.15b1481d443cf052e171454554b3cbc9.jpg: 448x800 11 masks, 21.7ms
# image 62/200 /content/datasets/Mask-Wearing-19/test/images/RPReplay_Final1667001201_MP4-126_jpg.rf.2de80f6821a492c9af3285a036d85076.jpg: 800x800 1 mask, 25.9ms
# image 63/200 /content/datasets/Mask-Wearing-19/test/images/RPReplay_Final1667001201_MP4-141_jpg.rf.4c89348b67d091dd91115a6fb2df19a3.jpg: 800x800 1 mask, 29.9ms
# image 64/200 /content/datasets/Mask-Wearing-19/test/images/RPReplay_Final1667001201_MP4-151_jpg.rf.b9c86a8915d99536509df9ada08d0b13.jpg: 800x800 1 mask, 24.7ms
# image 65/200 /content/datasets/Mask-Wearing-19/test/images/RPReplay_Final1667001201_MP4-163_jpg.rf.76c81146cb10eaac4b7ee53de943e433.jpg: 800x800 1 no-mask, 24.7ms
# image 66/200 /content/datasets/Mask-Wearing-19/test/images/RPReplay_Final1667001201_MP4-186_jpg.rf.3e066ef4ef4ae6c3308ee9ee3f3619e6.jpg: 800x800 1 no-mask, 30.0ms
# image 67/200 /content/datasets/Mask-Wearing-19/test/images/RPReplay_Final1667001201_MP4-199_jpg.rf.6236afd65e38ca437879bee0158a8726.jpg: 800x800 1 no-mask, 25.0ms
# image 68/200 /content/datasets/Mask-Wearing-19/test/images/RPReplay_Final1667001201_MP4-202_jpg.rf.1acfec8a03cca5757ab444a2e44be1c4.jpg: 800x800 1 no-mask, 24.7ms
# image 69/200 /content/datasets/Mask-Wearing-19/test/images/RPReplay_Final1667001201_MP4-203_jpg.rf.fc62bbf960a6c111b66eed7f64b0026e.jpg: 800x800 1 no-mask, 24.7ms
# image 85/200 /content/datasets/Mask-Wearing-19/test/images/RPReplay_Final1667001201_MP4-329_jpg.rf.5d98282acb21f6ed0250483c9a25e624.jpg: 800x800 1 mask, 24.6ms
# image 86/200 /content/datasets/Mask-Wearing-19/test/images/RPReplay_Final1667001201_MP4-351_jpg.rf.d24bc877aaaa7f9b5d5af3e1fc916f17.jpg: 800x800 1 mask, 24.6ms
# image 87/200 /content/datasets/Mask-Wearing-19/test/images/RPReplay_Final1667001201_MP4-360_jpg.rf.414a91110e7539b1713c7ed8f680ce9e.jpg: 800x800 1 mask, 24.6ms
# image 88/200 /content/datasets/Mask-Wearing-19/test/images/RPReplay_Final1667001201_MP4-362_jpg.rf.549edde4964c3e9a8d2cd2f7d947f5fc.jpg: 800x800 1 mask, 20.4ms
# image 89/200 /content/datasets/Mask-Wearing-19/test/images/RPReplay_Final1667001201_MP4-36_jpg.rf.b361f79d891840b163515158fb9338c1.jpg: 800x800 1 mask, 20.4ms
# image 90/200 /content/datasets/Mask-Wearing-19/test/images/RPReplay_Final1667001201_MP4-379_jpg.rf.8f346a652a8a2830236bf1634246dc51.jpg: 800x800 1 mask, 20.5ms
# image 91/200 /content/datasets/Mask-Wearing-19/test/images/RPReplay_Final1667001201_MP4-381_jpg.rf.980edd684ff29c20278a0e0c8125c6a2.jpg: 800x800 1 mask, 20.8ms
# image 92/200 /content/datasets/Mask-Wearing-19/test/images/RPReplay_Final1667001201_MP4-394_jpg.rf.592ee15abdf504abaee7e36469039292.jpg: 800x800 1 mask, 19.8ms
# image 93/200 /content/datasets/Mask-Wearing-19/test/images/RPReplay_Final1667001201_MP4-396_jpg.rf.51a73edd525dcf6297d5e928aae4abca.jpg: 800x800 1 mask, 19.8ms
# image 94/200 /content/datasets/Mask-Wearing-19/test/images/RPReplay_Final1667001201_MP4-402_jpg.rf.2eac312eb532fff1de6674545170ca27.jpg: 800x800 1 mask, 19.8ms
# image 95/200 /content/datasets/Mask-Wearing-19/test/images/RPReplay_Final1667001201_MP4-405_jpg.rf.9543195423e69befd1d06b5070d3ff52.jpg: 800x800 1 mask, 19.8ms
# image 96/200 /content/datasets/Mask-Wearing-19/test/images/RPReplay_Final1667001201_MP4-407_jpg.rf.5e6db88aa9d8e8ffd5f59a0f249e932b.jpg: 800x800 1 mask, 19.5ms
# image 97/200 /content/datasets/Mask-Wearing-19/test/images/RPReplay_Final1667001201_MP4-42_jpg.rf.901345410c0736ba1036db4d6ab49071.jpg: 800x800 1 mask, 19.5ms
# image 98/200 /content/datasets/Mask-Wearing-19/test/images/RPReplay_Final1667001201_MP4-432_jpg.rf.5ed590b47f0692fbb9416b289ba13ddd.jpg: 800x800 1 mask, 19.5ms
# image 99/200 /content/datasets/Mask-Wearing-19/test/images/RPReplay_Final1667001201_MP4-440_jpg.rf.8184132dddf39632bb7e843d88ed40e5.jpg: 800x800 1 mask, 19.6ms
# image 100/200 /content/datasets/Mask-Wearing-19/test/images/RPReplay_Final1667001201_MP4-450_jpg.rf.d9773bcc096da1339a34115aea59642f.jpg: 800x800 1 mask, 19.1ms
# image 116/200 /content/datasets/Mask-Wearing-19/test/images/Untitled-design-13_png_jpg.rf.9fcc25fc0010c19f9ed5e1d26dc0fda2.jpg: 480x800 1 mask, 11.4ms
# image 117/200 /content/datasets/Mask-Wearing-19/test/images/YouTube-FREE-AerialStockFootage_CityUrban-YKY3Mm5P1tE-720p_mp4-21_jpg.rf.734c6f0434c23c76b682ccad25815c71.jpg: 480x800 10.5ms
# image 118/200 /content/datasets/Mask-Wearing-19/test/images/YouTube-FREE-AerialStockFootage_CityUrban-YKY3Mm5P1tE-720p_mp4-23_jpg.rf.4d695ef415734ca6b790c3be1848f447.jpg: 480x800 10.5ms
# image 119/200 /content/datasets/Mask-Wearing-19/test/images/YouTube-FREE-AerialStockFootage_CityUrban-YKY3Mm5P1tE-720p_mp4-33_jpg.rf.983a2106a01373d271e24127378133b7.jpg: 480x800 10.6ms
# image 120/200 /content/datasets/Mask-Wearing-19/test/images/YouTube-FREE-AerialStockFootage_CityUrban-YKY3Mm5P1tE-720p_mp4-35_jpg.rf.c9e211e0e9d4fe8fded66af4348c462f.jpg: 480x800 10.6ms
# image 121/200 /content/datasets/Mask-Wearing-19/test/images/YouTube-FREE-AerialStockFootage_CityUrban-YKY3Mm5P1tE-720p_mp4-40_jpg.rf.9d2ee3cfda3504ac5a12dbb4c2f12c1e.jpg: 480x800 10.5ms
# image 122/200 /content/datasets/Mask-Wearing-19/test/images/YouTube-FREE-AerialStockFootage_CityUrban-YKY3Mm5P1tE-720p_mp4-60_jpg.rf.e8f27ef3425445881d6a2175e312011f.jpg: 480x800 10.6ms
# image 123/200 /content/datasets/Mask-Wearing-19/test/images/YouTube-FREE-AerialStockFootage_CityUrban-YKY3Mm5P1tE-720p_mp4-64_jpg.rf.b285b2a29ad69ba0981528ae965da760.jpg: 480x800 10.6ms
# image 124/200 /content/datasets/Mask-Wearing-19/test/images/YouTube-FREE-AerialStockFootage_CityUrban-YKY3Mm5P1tE-720p_mp4-9_jpg.rf.09ad499a2f0b2752e8b3f74517ce98a2.jpg: 480x800 10.6ms
# image 125/200 /content/datasets/Mask-Wearing-19/test/images/YouTube-FreeStockFootage-PersonThinkingDeeply-h-HC--hj-Zo-720p_mp4-14_jpg.rf.566655e00b6af1ef357dfb9200774e36.jpg: 480x800 2 no-masks, 10.6ms
# image 126/200 /content/datasets/Mask-Wearing-19/test/images/YouTube-FreeStockFootage-PersonThinkingDeeply-h-HC--hj-Zo-720p_mp4-27_jpg.rf.d568874d8f50207b64d10e8e96ca19b4.jpg: 480x800 2 no-masks, 10.6ms
# image 127/200 /content/datasets/Mask-Wearing-19/test/images/YouTube-FreeStockFootage-PersonThinkingDeeply-h-HC--hj-Zo-720p_mp4-6_jpg.rf.b159b15ea8e678459b785df43886ac99.jpg: 480x800 1 no-mask, 14.6ms
# image 128/200 /content/datasets/Mask-Wearing-19/test/images/YouTube-FreeStockFootage-PersonThinkingDeeply-h-HC--hj-Zo-720p_mp4-7_jpg.rf.ecbeba42cc9717f44ea8f6c774dbacd6.jpg: 480x800 1 no-mask, 14.8ms
# image 129/200 /content/datasets/Mask-Wearing-19/test/images/YouTube-FreeStockFootage_Child-playing-with-parents-JoyLaughterHD-RQ_qqCZOkZk-720p_mp4-13_jpg.rf.8e38bd1929b451f8ba29208ad87f4f17.jpg: 480x800 2 no-masks, 14.8ms
# image 130/200 /content/datasets/Mask-Wearing-19/test/images/YouTube-FreeStockFootage_Child-playing-with-parents-JoyLaughterHD-RQ_qqCZOkZk-720p_mp4-21_jpg.rf.f02875d8697bb5a6a61a775315470e4d.jpg: 480x800 1 mask, 2 no-masks, 15.1ms
# image 131/200 /content/datasets/Mask-Wearing-19/test/images/YouTube-FreeStockFootage_Child-playing-with-parents-JoyLaughterHD-RQ_qqCZOkZk-720p_mp4-23_jpg.rf.9ce87030fbf0a513eb9f33ee4d0654e4.jpg: 480x800 2 no-masks, 15.1ms
# image 132/200 /content/datasets/Mask-Wearing-19/test/images/YouTube-FreeStockFootage_Child-playing-with-parents-JoyLaughterHD-RQ_qqCZOkZk-720p_mp4-27_jpg.rf.bfa71fd94d35634959c94354c9fb99e2.jpg: 480x800 1 no-mask, 15.2ms
# image 133/200 /content/datasets/Mask-Wearing-19/test/images/YouTube-FreeStockFootage_Child-playing-with-parents-JoyLaughterHD-RQ_qqCZOkZk-720p_mp4-4_jpg.rf.f3471484e1c61c6f69127c5e92356cdd.jpg: 480x800 15.3ms
# image 134/200 /content/datasets/Mask-Wearing-19/test/images/YouTube_FreeStockFootage_People-wearing-face-mask_Empty-Street_Covid19-D_DbgrvhlGs-720p_mp4-24_jpg.rf.cccfd79441d1faef47c610ff99102f9f.jpg: 480x800 1 mask, 1 no-mask, 15.4ms
# image 135/200 /content/datasets/Mask-Wearing-19/test/images/YouTube_FreeStockFootage_People-wearing-face-mask_Empty-Street_Covid19-D_DbgrvhlGs-720p_mp4-35_jpg.rf.a365624e2397dd55738e51e79d5b7e27.jpg: 480x800 1 mask, 15.4ms
# image 136/200 /content/datasets/Mask-Wearing-19/test/images/YouTube_FreeStockFootage_People-wearing-face-mask_Empty-Street_Covid19-D_DbgrvhlGs-720p_mp4-41_jpg.rf.1b5980f90b907f97d6d4b8c16468df70.jpg: 480x800 2 masks, 15.4ms
# image 137/200 /content/datasets/Mask-Wearing-19/test/images/YouTube_FreeStockFootage_People-wearing-face-mask_Empty-Street_Covid19-D_DbgrvhlGs-720p_mp4-44_jpg.rf.5a101e7d94447e748baf5921ea07084f.jpg: 480x800 2 masks, 15.4ms
# image 138/200 /content/datasets/Mask-Wearing-19/test/images/YouTube_FreeStockFootage_People-wearing-face-mask_Empty-Street_Covid19-D_DbgrvhlGs-720p_mp4-47_jpg.rf.97e1da607a47f3d038a15436e0b3f6d1.jpg: 480x800 1 mask, 15.4ms
# image 139/200 /content/datasets/Mask-Wearing-19/test/images/YouTube_FreeStockFootage_People-wearing-face-mask_Empty-Street_Covid19-D_DbgrvhlGs-720p_mp4-56_jpg.rf.ac69a2f6d5e7da6d637ac409d348406b.jpg: 480x800 15.4ms
# image 140/200 /content/datasets/Mask-Wearing-19/test/images/YouTube_FreeStockFootage_People-wearing-face-mask_Empty-Street_Covid19-D_DbgrvhlGs-720p_mp4-59_jpg.rf.50d4ead9bb79ef1aa3a71a270a171bb3.jpg: 480x800 15.4ms
# image 141/200 /content/datasets/Mask-Wearing-19/test/images/YouTube_FreeStockFootage_People-wearing-face-mask_Empty-Street_Covid19-D_DbgrvhlGs-720p_mp4-64_jpg.rf.3d7ad1f8b34a5f800a4124aa459aa9eb.jpg: 480x800 15.4ms
# image 142/200 /content/datasets/Mask-Wearing-19/test/images/YouTube_FreeStockFootage_People-wearing-face-mask_Empty-Street_Covid19-D_DbgrvhlGs-720p_mp4-68_jpg.rf.6f49125aa37b2f33684fce26445ee134.jpg: 480x800 15.4ms
# image 143/200 /content/datasets/Mask-Wearing-19/test/images/additional_tests-Nomask-wearing_mp4-15_jpg.rf.5cd7d3379a5afb117ca979f1696bf923.jpg: 608x800 1 no-mask, 20.2ms
# image 144/200 /content/datasets/Mask-Wearing-19/test/images/additional_tests-Nomask-wearing_mp4-19_jpg.rf.9d18d27addd0c074754891f863188b2b.jpg: 608x800 1 no-mask, 18.4ms
# image 145/200 /content/datasets/Mask-Wearing-19/test/images/additional_tests-Nomask-wearing_mp4-20_jpg.rf.c7d496948a4d2028f16e1700c284da2d.jpg: 608x800 1 no-mask, 18.4ms
# image 146/200 /content/datasets/Mask-Wearing-19/test/images/additional_tests-Nomask-wearing_mp4-25_jpg.rf.ed98dccb86b611660003a43c56c5b36e.jpg: 608x800 1 no-mask, 18.3ms
# image 147/200 /content/datasets/Mask-Wearing-19/test/images/boxesOnConveyer_mp4-4_jpg.rf.e01969461ee2a9be2dc7eceeb439c867.jpg: 480x800 17.4ms
# image 148/200 /content/datasets/Mask-Wearing-19/test/images/boxesOnConveyer_mp4-9_jpg.rf.bdb6f93ab96f51136d97c3d00b6e3c66.jpg: 480x800 15.5ms
# image 149/200 /content/datasets/Mask-Wearing-19/test/images/images--48-_jpeg.rf.24d082c11475f1b10c3ae094e69a3eab.jpg: 800x800 25.6ms
# image 150/200 /content/datasets/Mask-Wearing-19/test/images/images--56-_jpeg.rf.3fd1aa0f2aeaf3d978b70e793cf8014f.jpg: 384x800 2 no-masks, 96.2ms
# image 151/200 /content/datasets/Mask-Wearing-19/test/images/maksssksksss202_png.rf.40700cd94b25471b55d5470df864ba70.jpg: 608x800 8 masks, 1 no-mask, 19.3ms
# image 152/200 /content/datasets/Mask-Wearing-19/test/images/maksssksksss533_png.rf.3c63cbc30cb29c12f411d260c3840f57.jpg: 800x608 1 mask, 100.2ms
# image 153/200 /content/datasets/Mask-Wearing-19/test/images/maksssksksss99_png.rf.83497858bd2a672e47abe321582285b4.jpg: 544x800 4 masks, 18.6ms
# image 154/200 /content/datasets/Mask-Wearing-19/test/images/mask-wearing-tests_mohamed_mp4-18_jpg.rf.e2cf7e1a0cba6bbbe2f4edf8e51f8322.jpg: 608x800 1 no-mask, 19.4ms
# image 155/200 /content/datasets/Mask-Wearing-19/test/images/mask-wearing-tests_mohamed_mp4-49_jpg.rf.32270a2ab85fc7bf15239c481f251a79.jpg: 608x800 1 no-mask, 18.4ms
# image 156/200 /content/datasets/Mask-Wearing-19/test/images/mask-wearing-tests_mohamed_mp4-53_jpg.rf.c8ede4bbb2d96ba05d59065f1845e6e0.jpg: 608x800 1 no-mask, 18.4ms
# image 157/200 /content/datasets/Mask-Wearing-19/test/images/mask-wearing-tests_mohamed_mp4-70_jpg.rf.45e638ab5174497551955d4a219f5b9c.jpg: 608x800 1 no-mask, 18.4ms
# image 158/200 /content/datasets/Mask-Wearing-19/test/images/mask-wearing-tests_mohamed_mp4-72_jpg.rf.b3305124e543d63b6e2d588d4bb0348f.jpg: 608x800 1 no-mask, 18.4ms
# image 159/200 /content/datasets/Mask-Wearing-19/test/images/mask-wearing-tests_mohamed_mp4-74_jpg.rf.668b6c1c584084dafa972c50d93bba42.jpg: 608x800 1 no-mask, 18.3ms
# image 160/200 /content/datasets/Mask-Wearing-19/test/images/mask-wearing-tests_mohamed_mp4-78_jpg.rf.7caf23a443b720d308cf052e09a68728.jpg: 608x800 1 no-mask, 18.4ms
# image 161/200 /content/datasets/Mask-Wearing-19/test/images/mask-wearing-tests_mohamed_mp4-7_jpg.rf.2c03d3cc262bec775e245d01bdf11805.jpg: 608x800 1 no-mask, 17.7ms
# image 162/200 /content/datasets/Mask-Wearing-19/test/images/mask-wearing-tests_mohamed_mp4-90_jpg.rf.195e3017c217e5fc104c4d9914c7cbf1.jpg: 608x800 1 no-mask, 14.7ms
# image 163/200 /content/datasets/Mask-Wearing-19/test/images/mask-wearing-tests_mohamed_mp4-97_jpg.rf.630cc3b15f8cdea946a3e41271090b9f.jpg: 608x800 1 no-mask, 14.7ms
# image 164/200 /content/datasets/Mask-Wearing-19/test/images/mask-wearing-tests_mohamed_mp4-9_jpg.rf.ac566789de0e0a97ae70e817e7a2d8b8.jpg: 608x800 1 no-mask, 14.7ms
# image 165/200 /content/datasets/Mask-Wearing-19/test/images/mo-justin-mask-NoMask_mov-34_jpg.rf.765573ec8d68593d62a95a6756a6f52c.jpg: 800x736 1 mask, 1 no-mask, 17.7ms
# image 166/200 /content/datasets/Mask-Wearing-19/test/images/mo-justin-mask-NoMask_mov-35_jpg.rf.d98c5fd9f1df90d2babed977b1e7f783.jpg: 800x736 2 no-masks, 17.2ms
# image 167/200 /content/datasets/Mask-Wearing-19/test/images/mo-justin-mask-NoMask_mov-4_jpg.rf.cca71ba786d75d43949f7e7f57b3f0b0.jpg: 800x736 2 no-masks, 17.2ms
# image 168/200 /content/datasets/Mask-Wearing-19/test/images/mo-justin-mask-NoMask_mov-9_jpg.rf.894c4b12b795dc5857d525aa511bc660.jpg: 800x736 2 no-masks, 17.2ms
# image 169/200 /content/datasets/Mask-Wearing-19/test/images/no-mask_mov-13_jpg.rf.0312849b68281b2a03245f82cb3bf295.jpg: 544x800 1 no-mask, 15.1ms
# image 170/200 /content/datasets/Mask-Wearing-19/test/images/no-mask_mov-25_jpg.rf.8183d439714512449011d8e6c9225169.jpg: 544x800 1 no-mask, 14.1ms
# image 171/200 /content/datasets/Mask-Wearing-19/test/images/no-mask_mov-5_jpg.rf.f04b0beac4d78aa0dde6e4961668f018.jpg: 544x800 1 no-mask, 14.1ms
# image 172/200 /content/datasets/Mask-Wearing-19/test/images/phplpE73q_jpg.rf.3e59df9bd9bca29cdd3a79816fcf36c9.jpg: 544x800 42 masks, 2 no-masks, 14.1ms
# image 173/200 /content/datasets/Mask-Wearing-19/test/images/phplpE73q_jpg.rf.6238e50576c7728aa925e79276e023e0.jpg: 544x800 40 masks, 2 no-masks, 14.2ms
# image 174/200 /content/datasets/Mask-Wearing-19/test/images/pollution-mask-CE5HYF_jpg.rf.a1aaac2f6f27a970e0af03fcc9d66c17.jpg: 608x800 2 masks, 15.9ms
# image 175/200 /content/datasets/Mask-Wearing-19/test/images/r1p00017o8171pnq407_jpg.rf.1a34bf9c5dc2f3bda65e431640cb794f.jpg: 800x544 2 masks, 16.1ms
# image 176/200 /content/datasets/Mask-Wearing-19/test/images/r1p00017o8171pnq407_jpg.rf.2917f6df08219fe7b8eb8323799163eb.jpg: 800x544 2 masks, 15.0ms
# image 177/200 /content/datasets/Mask-Wearing-19/test/images/sars-gettyimages-157005245_jpg.rf.757f39c5519565b1bb9818b4c72eb335.jpg: 480x800 4 masks, 13.3ms
# image 178/200 /content/datasets/Mask-Wearing-19/test/images/shutterstock_1627199179_jpg.rf.49387c5a5370e9eb0ed81af79a68058d.jpg: 544x800 5 masks, 15.9ms
# image 179/200 /content/datasets/Mask-Wearing-19/test/images/shutterstock_1627199179_jpg.rf.89a42e1721c39e5cbd27356f701d4a53.jpg: 544x800 5 masks, 20.8ms
# image 180/200 /content/datasets/Mask-Wearing-19/test/images/stsciRq_png_jpg.rf.a7d587db9c45a1cf27fdd6f3d03ff7b6.jpg: 800x416 3 masks, 114.5ms
# image 181/200 /content/datasets/Mask-Wearing-19/test/images/the-first-day-of-wuhan-s-closure-some-people-fled-some-panicked_jpg.rf.3d263541f0002eed4a6c08f46096ef22.jpg: 480x800 4 masks, 3 no-masks, 31.2ms
# image 182/200 /content/datasets/Mask-Wearing-19/test/images/the-first-day-of-wuhan-s-closure-some-people-fled-some-panicked_jpg.rf.d4869f11879ab96b2671b1ec4e0fabb9.jpg: 480x800 4 masks, 3 no-masks, 23.6ms
# image 183/200 /content/datasets/Mask-Wearing-19/test/images/virus_protection123_jpg.rf.3d58d10f753093e7ccfe652b29b823f6.jpg: 608x800 5 masks, 15.8ms
# image 184/200 /content/datasets/Mask-Wearing-19/test/images/w1240-p16x9-0e48e0098f6e832f27d8b581b33bbc72b9967a63_jpg.rf.ac86a51ac7e6926c871d825d474bdb48.jpg: 480x800 2 masks, 16.4ms
# image 185/200 /content/datasets/Mask-Wearing-19/test/images/w1240-p16x9-0e48e0098f6e832f27d8b581b33bbc72b9967a63_jpg.rf.c32f0e956faefc04894c6e3085214a4d.jpg: 480x800 2 masks, 15.5ms
# image 186/200 /content/datasets/Mask-Wearing-19/test/images/w1240-p16x9-2019-10-04t075956z_1862636027_rc15d4d49d00_rtrmadp_3_hongkong-protests_jpg.rf.ca3484e9600ad8c614bc593c75c5e1c2.jpg: 480x800 17 masks, 15.7ms
# image 187/200 /content/datasets/Mask-Wearing-19/test/images/w1240-p16x9-fa978043deff83fed485af12d16e39c61398fc30_jpg.rf.8382ac4de8b3ea8510a86f8ccc32dd2a.jpg: 480x800 3 masks, 15.5ms
# image 188/200 /content/datasets/Mask-Wearing-19/test/images/youtube-107_jpg.rf.9b51d4c6590f5c3222379611164d6a4d.jpg: 480x800 15.5ms
# image 189/200 /content/datasets/Mask-Wearing-19/test/images/youtube-21_jpg.rf.4184ec4279e83e3e555a2450b48c4b03.jpg: 480x800 15.5ms
# image 190/200 /content/datasets/Mask-Wearing-19/test/images/youtube-35_jpg.rf.eede6a0a58bff4604826fec5b963b1fb.jpg: 480x800 19.8ms
# image 191/200 /content/datasets/Mask-Wearing-19/test/images/youtube-41_jpg.rf.2e1cf7633c7d8db0c2301de21eb3e2a9.jpg: 480x800 15.5ms
# image 192/200 /content/datasets/Mask-Wearing-19/test/images/youtube-59_jpg.rf.823a510296cfcf5dea927bd311832d89.jpg: 480x800 19.2ms
# image 193/200 /content/datasets/Mask-Wearing-19/test/images/youtube-62_jpg.rf.8ae82d392da708e1df285053168c2ac9.jpg: 480x800 15.5ms
# image 194/200 /content/datasets/Mask-Wearing-19/test/images/youtube-77_jpg.rf.91aeb12cb2b1f981455d8d89e891cd74.jpg: 480x800 15.5ms
# image 195/200 /content/datasets/Mask-Wearing-19/test/images/youtube-79_jpg.rf.32c66a55eac4be6862b9a39df2fdfddd.jpg: 480x800 15.5ms
# image 196/200 /content/datasets/Mask-Wearing-19/test/images/youtube-85_jpg.rf.a8061a0713de61a8cd7c127cbce71f95.jpg: 480x800 15.5ms
# image 197/200 /content/datasets/Mask-Wearing-19/test/images/youtube-86_jpg.rf.cfc40691d4c1180408fdd1839a4a72db.jpg: 480x800 18.3ms
# image 198/200 /content/datasets/Mask-Wearing-19/test/images/youtube-90_jpg.rf.e3aa025e866bd79eb405d440915f6acf.jpg: 480x800 16.5ms
# image 199/200 /content/datasets/Mask-Wearing-19/test/images/youtube-92_jpg.rf.c76952a99ad27f14b66bc3193704c5ac.jpg: 480x800 15.5ms
# image 200/200 /content/datasets/Mask-Wearing-19/test/images/youtube-9_jpg.rf.4be81a2879a561da97da5734e70efb41.jpg: 480x800 15.5ms
# Speed: 0.7ms pre-process, 23.9ms inference, 2.5ms postprocess per image at shape (1, 3, 800, 800)
# Results saved to runs/detect/predict2

# %% [markdown]
# **NOTE:** Let's take a look at few results.

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/detect/predict3/*.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")
