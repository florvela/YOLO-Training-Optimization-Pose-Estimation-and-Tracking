# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
import os
# Out:
# Mounted at /content/drive

# %%
def swap_first_zero_and_one(line):
    first_zero_index = line.find('0')
    first_one_index = line.find('1')

    if first_zero_index < first_one_index or first_one_index == -1:
        line = line[:first_zero_index] + '1' + line[first_zero_index + 1:]
    else:
        line = line[:first_one_index] + '0' + line[first_one_index + 1:]

    return line

def process_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()

    with open(file_path, 'w') as file:
        for line in lines:
            processed_line = swap_first_zero_and_one(line)
            file.write(processed_line)

def process_directory(directory_path):
    for root, _, files in os.walk(directory_path):
        for file in files:
            file_path = os.path.join(root, file)
            print(file_path)
            process_file(file_path)

# %%
# file_path = "/content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov8_tests/test/labels/knife_1160_jpg.rf.fe471dfbc4c16daf48f7219fc6af5c14.txt"
# file_path = "/content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov8_tests/test/labels/knife_1107_jpg.rf.d215a9058b2a398750562baa37af0180.txt"
# file_path = "/content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov8_tests/test/labels/batch_980_jpg.rf.334c0350bce4913b9e8eed50c7b7cd2c.txt"
# file_path = "/content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov8_tests/test/labels/05_14_0000047_jpg.rf.2507a9f794f02c702ac788ccfc53f8d8.txt"
# process_file(file_path)

# %%
labels_folder = "/content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov8_big/test/labels"
process_directory(labels_folder)
# Out:
# /content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov8_big/test/labels/05_14_0000047_jpg.rf.2507a9f794f02c702ac788ccfc53f8d8.txt
# /content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov8_big/test/labels/05_14_0000059_jpg.rf.1ee0b900ec63e4012ba50a4247b2bdc7.txt
# /content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov8_big/test/labels/05_14_0000414_jpg.rf.7d3a78ed8b6e008f4c93a49fc039829f.txt
# /content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov8_big/test/labels/05_14_0000556_jpg.rf.b77ffbd781aa30e506cd7639b7b32038.txt
# /content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov8_big/test/labels/1000mabuse-dreyse01_jpg.rf.caf3b28142b1e2e6d9d639947fe739d3.txt
# /content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov8_big/test/labels/100_jpg.rf.de9e41220d963225496c1561bcee3f9d.txt
# ...

# %%
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="")
# project = rf.workspace("crime-detection").project("guns_n_knives-h4bky")
# dataset = project.version(3).download("yolov5", location="/content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov5_big")

# %%
# !ls /content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov5_big/test/labels

# %%
labels_folder = "/content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov7_big/test/labels"
process_directory(labels_folder)
# Out:
# /content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov7_big/test/labels/05_14_0000047_jpg.rf.2507a9f794f02c702ac788ccfc53f8d8.txt
# /content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov7_big/test/labels/05_14_0000059_jpg.rf.1ee0b900ec63e4012ba50a4247b2bdc7.txt
# /content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov7_big/test/labels/05_14_0000414_jpg.rf.7d3a78ed8b6e008f4c93a49fc039829f.txt
# /content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov7_big/test/labels/05_14_0000556_jpg.rf.b77ffbd781aa30e506cd7639b7b32038.txt
# /content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov7_big/test/labels/1000mabuse-dreyse01_jpg.rf.caf3b28142b1e2e6d9d639947fe739d3.txt
# /content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov7_big/test/labels/100_jpg.rf.de9e41220d963225496c1561bcee3f9d.txt
# ...

# %%
labels_folder = "/content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov5_big/test/labels"
process_directory(labels_folder)
# Out:
# /content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov5_big/test/labels/05_14_0000047_jpg.rf.2507a9f794f02c702ac788ccfc53f8d8.txt
# /content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov5_big/test/labels/05_14_0000059_jpg.rf.1ee0b900ec63e4012ba50a4247b2bdc7.txt
# /content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov5_big/test/labels/05_14_0000414_jpg.rf.7d3a78ed8b6e008f4c93a49fc039829f.txt
# /content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov5_big/test/labels/05_14_0000556_jpg.rf.b77ffbd781aa30e506cd7639b7b32038.txt
# /content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov5_big/test/labels/1000mabuse-dreyse01_jpg.rf.caf3b28142b1e2e6d9d639947fe739d3.txt
# /content/drive/MyDrive/trabajo_final_CEIA/train_models/datasets/yolov5_big/test/labels/100_jpg.rf.de9e41220d963225496c1561bcee3f9d.txt
# ...
